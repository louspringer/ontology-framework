# %%
import pandas as pd

# %%
# !pip freeze
# Out:
# absl-py==2.2.2
# altair @ file:///private/var/folders/c_/qfmhj66j0tn016nkx_th4hxm0000gp/T/abs_27xju4dqjd/croot/altair_1743016730076/work
# annotated-types==0.7.0
# anyio @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_14cmpboz6t/croot/anyio_1745334650823/work
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1733332318622/work
# argcomplete==3.5.3
# argon2-cffi @ file:///opt/conda/conda-bld/argon2-cffi_1645000214183/work
# argon2-cffi-bindings @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_a2dqjqi0nt/croot/argon2-cffi-bindings_1736182447763/work
# astroid @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_e5jtinued7/croot/astroid_1736455939952/work
# asttokens @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_15z9et5x6m/croot/asttokens_1743630451525/work
# astunparse==1.6.3
# ...

# %%
vms = !az vm list
json_str = '\n'.join(vms)
data = json.loads(json_str)
data
# Out:
# [{'additionalCapabilities': None,
#   'applicationProfile': None,
#   'availabilitySet': None,
#   'billingProfile': {'maxPrice': -1.0},
#   'capacityReservation': None,
#   'diagnosticsProfile': None,
#   'etag': '"17"',
#   'evictionPolicy': 'Deallocate',
#   'extendedLocation': None,
#   'extensionsTimeBudget': None,
#   'hardwareProfile': {'vmSize': 'Standard_D4s_v3', 'vmSizeProperties': None},
#   'host': None,
#   'hostGroup': None,
#   'id': '/subscriptions/dae16755-7832-4e6d-bae2-c49ff833042f/resourceGroups/BALDO-DEVBOX-RG/providers/Microsoft.Compute/virtualMachines/baldo-devbox',
#   'identity': None,
#   'instanceView': None,
#   'licenseType': None,
#   'location': 'westus',
#   'managedBy': None,
#   'name': 'baldo-devbox',
#   'networkProfile': {'networkApiVersion': None,
#    'networkInterfaceConfigurations': None,
#    'networkInterfaces': [{'deleteOption': None,
# ...

# %%
df = pd.json_normalize(data)
df
# Out:
#   additionalCapabilities applicationProfile availabilitySet  \
# 0                   None               None            None
#
#   capacityReservation diagnosticsProfile  etag evictionPolicy  \
# 0                None               None  "17"     Deallocate
#
#   extendedLocation extensionsTimeBudget  host  ...  \
# 0             None                 None  None  ...
#
#   storageProfile.osDisk.image  \
# 0                        None
#
#   storageProfile.osDisk.managedDisk.diskEncryptionSet  \
# 0                                               None
#
#                 storageProfile.osDisk.managedDisk.id  \
# 0  /subscriptions/dae16755-7832-4e6d-bae2-c49ff83...
#
#   storageProfile.osDisk.managedDisk.resourceGroup  \
# 0                                 BALDO-DEVBOX-RG
#
#   storageProfile.osDisk.managedDisk.securityProfile  \
# 0                                              None
#
#   storageProfile.osDisk.managedDisk.storageAccountType  \
# ...
